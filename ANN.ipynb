# %%
import tensorflow as tf 
import pandas as pd 
import matplotlib.pyplot as plt 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Flatten, Dense 
from tensorflow.keras.utils import to_categorical

# %%
train_df = pd.read_csv("mnist_train.csv")
test_df = pd.read_csv("mnist_test.csv")
x_train = train_df.drop(columns = ['label']).values
x_test = test_df.drop(columns = ['label']).values
y_train = to_categorical(train_df['label'])
y_test = to_categorical(test_df['label'])
x_train = x_train.reshape(-1,28,28)
x_test= x_test.reshape(-1,28,28)
x_train = x_train/255.0
x_test= x_test/255.0
x_train = x_train.astype('float32')
x_test= x_test.astype('float32')

# %%
model = Sequential([
    Flatten(input_shape = (28,28)),
    Dense(128, activation='relu'),
    Dense(10, activation = 'softmax')
])

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics =['accuracy'])
history = model.fit(x_train, y_train, epochs=11)
# Out:
# Epoch 1/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 409us/step - accuracy: 0.8387 - loss: 0.6429
# Epoch 2/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 391us/step - accuracy: 0.9071 - loss: 0.3331
# Epoch 3/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 375us/step - accuracy: 0.9195 - loss: 0.2851
# Epoch 4/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 377us/step - accuracy: 0.9283 - loss: 0.2550
# Epoch 5/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 379us/step - accuracy: 0.9345 - loss: 0.2322
# Epoch 6/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 404us/step - accuracy: 0.9404 - loss: 0.2134
# Epoch 7/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - accuracy: 0.9443 - loss: 0.1977
# Epoch 8/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 390us/step - accuracy: 0.9479 - loss: 0.1842
# Epoch 9/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.9512 - loss: 0.1725
# Epoch 10/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 405us/step - accuracy: 0.9541 - loss: 0.1623
# Epoch 11/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 416us/step - accuracy: 0.9564 - loss: 0.1535

# %%
test_loss,test_acc = model.evaluate(x_test, y_test, verbose =0)
print(f"Test Accuracy: {test_acc: .4f}")
# Out:
# Test Accuracy:  0.9547

# %%
plt.plot(history.history['loss'], label = 'Training Loss')
plt.plot(history.history['accuracy'], label = 'Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.title('Training Loss and Accuracy')
plt.legend()
plt.show()

# %%
import tensorflow as tf 
import pandas as pd 
import matplotlib.pyplot as plt 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
train_df = pd.read_csv("cifar_train_data.csv")
test_df = pd.read_csv("cifar_test_data.csv")
x_train = train_df.drop(columns = ['label']).values
x_test = test_df.drop(columns = ['label']).values
y_train = to_categorical(train_df['label'])
y_test = to_categorical(test_df['label'])
x_train = x_train/255.0
x_test= x_test/255.0
x_train = x_train.reshape(-1,32,32,3)
x_test= x_test.reshape(-1,32,32,3)
x_train = x_train.astype('float32')
x_test= x_test.astype('float32')

# %%
model = Sequential([
    Flatten(input_shape = (32,32,3)),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train, y_train, epochs = 11)
# Out:
# Epoch 1/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.2497 - loss: 2.0129
# Epoch 2/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.2907 - loss: 1.9132
# Epoch 3/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3037 - loss: 1.8797
# Epoch 4/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3148 - loss: 1.8571
# Epoch 5/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3249 - loss: 1.8386
# Epoch 6/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3295 - loss: 1.8303
# Epoch 7/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3311 - loss: 1.8212
# Epoch 8/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3333 - loss: 1.8141
# Epoch 9/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3392 - loss: 1.8064
# Epoch 10/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3414 - loss: 1.8017
# Epoch 11/11
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3434 - loss: 1.7962

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc: .4f}")
# Out:
# Test Accuracy:  0.3899

# %%
plt.plot(history.history['loss'], label = 'Training Loss')
plt.plot(history.history['accuracy'], label = 'Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.title('Training Loss and Accuracy')
plt.legend()
plt.show()
