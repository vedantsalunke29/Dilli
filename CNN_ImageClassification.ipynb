# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
###Load
train_df = pd.read_csv("mnist_train.csv")
test_df = pd.read_csv("mnist_test.csv")
x_train = train_df.drop(columns=['label']).values
x_test = test_df.drop(columns=['label']).values
y_train = to_categorical(train_df['label'])
y_test = to_categorical(test_df['label'])
x_train = x_train/255.0
x_test = x_test/255.0
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# %%
### Model architecture
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape = (28,28,1)),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(64, activation = 'relu'),
    Dense(10, activation = 'softmax')
])

# %%
###Compilation and Training step
model.compile(optimizer='adam', loss ='categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train, y_train, epochs =5, validation_split=0.1)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9446 - loss: 0.1840 - val_accuracy: 0.9763 - val_loss: 0.0791
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9795 - loss: 0.0662 - val_accuracy: 0.9832 - val_loss: 0.0579
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9866 - loss: 0.0433 - val_accuracy: 0.9852 - val_loss: 0.0530
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9901 - loss: 0.0317 - val_accuracy: 0.9862 - val_loss: 0.0517
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9929 - loss: 0.0230 - val_accuracy: 0.9880 - val_loss: 0.0497

# %%
loss, acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.9854 - loss: 0.0467
# Test Accuracy: 0.9854

# %%
plt.plot(history.history['loss'], label = 'Training Loss')
plt.plot(history.history['accuracy'], label = 'Training Accuracy')
plt.plot(history.history['val_loss'], label = 'Training Val_Loss')
plt.plot(history.history['val_accuracy'], label = 'Training Val_Accuracy')
plt.legend()
plt.show()

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
###Load
train_df = pd.read_csv("cifar_train_data.csv")
test_df = pd.read_csv("cifar_test_data.csv")
x_train = train_df.drop(columns=['label']).values
x_test = test_df.drop(columns=['label']).values
y_train = to_categorical(train_df['label'])
y_test = to_categorical(test_df['label'])
x_train = x_train/255.0
x_test = x_test/255.0
x_train = x_train.reshape(-1,32,32,3)
x_test = x_test.reshape(-1,32,32,3)

# %%
### Model architecture
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape = (32,32,3)),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(64, activation = 'relu'),
    Dense(10, activation = 'softmax')
])

# %%
###Compilation and Training step
model.compile(optimizer='adam', loss ='categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train, y_train, epochs =5, validation_split=0.1)
# Out:
# Epoch 1/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.4829 - loss: 1.4568 - val_accuracy: 0.5826 - val_loss: 1.2153
# Epoch 2/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5936 - loss: 1.1628 - val_accuracy: 0.5966 - val_loss: 1.1436
# Epoch 3/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6354 - loss: 1.0422 - val_accuracy: 0.6252 - val_loss: 1.0822
# Epoch 4/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6670 - loss: 0.9588 - val_accuracy: 0.6384 - val_loss: 1.0439
# Epoch 5/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6911 - loss: 0.8845 - val_accuracy: 0.6374 - val_loss: 1.0605

# %%
loss, acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6293 - loss: 1.0619
# Test Accuracy: 0.6293

# %%
plt.plot(history.history['loss'], label = 'Training Loss')
plt.plot(history.history['accuracy'], label = 'Training Accuracy')
plt.plot(history.history['val_loss'], label = 'Training Val_Loss')
plt.plot(history.history['val_accuracy'], label = 'Training Val_Accuracy')
plt.legend()
plt.show()
